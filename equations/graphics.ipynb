# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output.csv')

# %%
df.loc[:,['azimuth','calc_azi']].plot(secondary_y=['calc_azi'], mark_right=False, figsize = (20,5), grid=True)
# Out:
# <AxesSubplot:>

# %%
df.loc[:,['inclination','calc_inc']].plot(secondary_y=['calc_azi'], mark_right=False, figsize = (20,5), grid=True)
# Out:
# <AxesSubplot:>

# %%
df[['calc_azi','azimuth']].tail(50)
# Out:
#      calc_azi   azimuth
# 245  3.526240  5.405634
# 246  3.550989  5.413488
# 247  3.532278  5.407554
# 248  3.481892  5.391497
# 249  3.479640  5.390798
# 250  3.497790  5.396558
# 251  3.501033  5.397605
# 252  3.474745  5.389228
# 253  3.571236  5.419945
# 254  3.575086  5.421167
# 255  3.585478  5.424483
# 256  3.572359  5.420295
# 257  3.575591  5.421342
# 258  3.574020  5.420818
# 259  3.542129  5.410695
# 260  3.563613  5.417502
# 261  3.544865  5.411568
# 262  3.514818  5.401969
# 263  3.504287  5.398652
# 264  3.522493  5.404412
# 265  3.514712  5.401969
# 266  3.501662  5.397780
# 267  3.490036  5.394115
# 268  3.509878  5.400398
# 269  3.514171  5.401794
# 270  3.499995  5.397256
# 271  3.484567  5.392369
# 272  3.475321  5.389402
# 273  3.541031  5.410346
# 274  3.547710  5.412441
# 275  3.544327  5.411393
# 276  3.526857  5.405808
# 277  3.538847  5.409648
# 278  3.544418  5.411393
# 279  3.518011  5.403016
# 280  3.457783  5.383817
# 281  3.441232  5.378581
# ...

# %%
df.max()
# Out:
# Unnamed: 0           294.000000
# tmd                 5320.000000
# delta_md              24.200000
# delta_ns              12.707730
# delta_ew               0.151258
# delta_tvd             24.199866
# inclination            1.616524
# azimuth                6.176720
# inclination_prev       1.616524
# azimuth_prev           6.176720
# calc_azi               6.252131
# calc_inc               3.139847
# dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# tmd                 0
# delta_md            0
# delta_ns            0
# delta_ew            0
# delta_tvd           0
# inclination         0
# azimuth             0
# inclination_prev    0
# azimuth_prev        0
# calc_azi            0
# calc_inc            0
# dtype: int64
